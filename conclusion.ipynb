# %% [markdown]
# ### 4. Conclusion

# %% [markdown]
# 1. De acuerdo a la matriz de correlación obtenida en el EDA, la variable con la mayor relación con la objetivo es ExternalRiskEstimate. Viendo los resultados de la parte 2 esto se confirma. Copio aqui la feature importance del arbol de decisión y la matriz de correlación para mostrarlo visualmente

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Observando los resultados de todos los algoritmos una vez entrenados con los parámetros optimos, previamente obtenidos por Cross-validation. Sugiero LDA y Naive Bayes como los mejores algoritmos para esta tarea de predicción, por haber obtenido dos de las mejores puntuaciones además de ser modelos muy simples y rápidos de entrenar, capazes de adaptarse perfectamente a la tarea. Adjunto la ROC curve.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. En este caso me han sorprendido los resultados de los algoritmos de clustering para la prediccion, obteniendo precisiones muy decentes, frente a los algoritmos de clasificación con mejores resultados. Siendo aún así más apropiado usar los algoritmos de clasificación, aprovechando que en este problema SI hay variable objetivo para entrenarlos.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
